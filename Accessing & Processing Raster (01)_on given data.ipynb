# %% [markdown]
# # LAB 01

# %% [markdown]
# ## Load Libraries

# %%
from rasterio.plot import show
import rasterio
import geotiff
import tifffile
from PIL import Image
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Raster

# %%
img = rasterio.open(r"G:\Personal\hyperspectral\New folder\Nawabshah_Landsat8.tif")
show(img)
# Out:
# <Axes: >

# %% [markdown]
# # To Display Metadata of Raster

# %%
with rasterio.open(r"G:\Personal\hyperspectral\New folder\Nawabshah_Landsat8.tif") as dataset:
    # Check the size (dimensions)
    width = dataset.width
    height = dataset.height
    print("Image Size (Width x Height):", width, "x", height)

    # Check the number of bands
    num_bands = dataset.count
    print("Number of Bands:", num_bands)
# Out:
# Image Size (Width x Height): 7681 x 7841
# Number of Bands: 3

# %%
dataset.count
dataset.width
dataset.height
# Out:
# 7841

# %% [markdown]
# # Using Matplotlib Library

# %%
plt.imread(r"G:\Personal\hyperspectral\New folder\Nawabshah_Landsat8.tif")
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 plt.imread(r"G:\Personal\hyperspectral\New folder\Nawabshah_Landsat8.tif")
#
# File ~\.conda\envs\Rasters\Lib\site-packages\matplotlib\pyplot.py:2195, in imread(fname, format)
#    2193 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2194 def imread(fname, format=None):
# -> 2195     return matplotlib.image.imread(fname, format)
#
# File ~\.conda\envs\Rasters\Lib\site-packages\matplotlib\image.py:1563, in imread(fname, format)
#    1556 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1557     # Pillow doesn't handle URLs directly.
#    1558     raise ValueError(
#    1559         "Please open the URL for reading and pass the "
#    1560         "result to Pillow, e.g. with "
#    1561         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1562         )
# -> 1563 with img_open(fname) as image:
#    1564     return (_pil_png_to_float_array(image)
#    1565             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1566             pil_to_array(image))
#
# File ~\.conda\envs\Rasters\Lib\site-packages\PIL\Image.py:3280, in open(fp, mode, formats)
#    3278     warnings.warn(message)
#    3279 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3280 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file 'G:\\Personal\\hyperspectral\\New folder\\Nawabshah_Landsat8.tif'

# %% [markdown]
# # Creating Array and acquiring Statistics

# %%
# Open the image
img = Image.open(r"G:\Personal\hyperspectral\01\HH-ALPSRP244140480-H2.2_UA.tif")

# Convert the image to a NumPy array
img_array = np.array(img)

# Calculate image statistics
mean = np.mean(img_array)
std_dev = np.std(img_array)
min = np.min(img_array)
max = np.max(img_array)

# Print the results
print("Mean:", mean)
print("Standard Deviation:", std_dev)
print("Min:", min)
print("Max:", max)

width, height = img.size
# Print the results
print("Width of Raster:", width)
print("Height of Raster:", height)
# Out:
# Mean: 2229.4633836132884
# Standard Deviation: 2965.282871694475
# Min: 0
# Max: 65535
# Width of Raster: 5700
# Height of Raster: 4700

# %% [markdown]
# # Reducing Size of the Raster

# %%
try:
    # Read image from disk.
    img = cv2.imread(r"G:\Personal\hyperspectral\01\HH-ALPSRP244140480-H2.2_UA.tif")
 
    # Get number of pixel horizontally and vertically. 
    (height, width) = img.shape[:2]    
 
    # Specify the size of image along with interpolation methods.
    # cv2.INTER_AREA is used for shrinking, whereas cv2.INTER_CUBIC
    # is used for zooming.
    res = cv2.resize(img, (int(width / 2), int(height / 2)), interpolation=cv2.INTER_CUBIC)
 
    # Write image back to disk.
    cv2.imwrite('result.tiff', res)
 
except IOError:
    print('Error while reading files !!!')
plt.imshow(res)

# %% [markdown]
# # Rotating Tiff Images

# %%
try:
    # Read image from disk.
    img = cv2.imread(r"G:\Personal\hyperspectral\01\HH-ALPSRP244140480-H2.2_UA.tif")
 
     # Shape of image in terms of pixels.
    (rows, cols) = img.shape[:2]
 
    # getRotationMatrix2D creates a matrix needed for transformation.
    # We want matrix for rotation w.r.t center to 45 degree without scaling.
    M = cv2.getRotationMatrix2D((cols / 2, rows / 2), 45, 1)
    res1 = cv2.warpAffine(img, M, (cols, rows))
 
    # Write image back to disk.
    cv2.imwrite('result.tiff', res1)
 
except IOError:
    print('Error while reading files !!!')
plt.imshow(res1)

# %% [markdown]
# # Translating Matrix

# %%
# Let's shift by (100, 50).
M = np.float32([[1, 0, 100], [0, 1, 50]])
try:
    # Read image from disk.
    img = cv2.imread(r"G:\Personal\hyperspectral\01\HH-ALPSRP244140480-H2.2_UA.tif")
 
     # warpAffine does appropriate shifting given the
    # translation matrix.
    res2 = cv2.warpAffine(img, M, (cols, rows))
 
    # Write image back to disk.
    cv2.imwrite('result.tiff', res2)
 
except IOError:
    print('Error while reading files !!!')
plt.imshow(res2)

# %% [markdown]
# # Canny Edge Detection

# %%
try:
    # Read image from disk.
    img = cv2.imread(r"G:\Personal\hyperspectral\01\HH-ALPSRP244140480-H2.2_UA.tif")
     
     # Canny edge detection.
    edges = cv2.Canny(img, 15, 10)
 
    # Write image back to disk.
    cv2.imwrite('result.tiff', edges)
 
except IOError:
    print('Error while reading files !!!')
plt.imshow(edges)

# %% [markdown]
# ## RGB

# %%
# Read the image
img2 = cv2.imread(r"G:\Personal\hyperspectral\01\HH-ALPSRP244140480-H2.2_UA.tif")

# Convert BGR to RGB color space (matplotlib expects RGB)
img2_rgb = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(img2_rgb)
plt.axis('off')  # Remove axis ticks and labels
plt.show()
